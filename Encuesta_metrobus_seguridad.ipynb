# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
#conectar con drive
drive.mount('/content/drive')
df=pd.read_csv("/content/drive/MyDrive/Datos/encuesta.csv")
# Out:
# Mounted at /content/drive

# %%
df
# Out:
#         id    linea                 estacion  4_sexo  \
# 0        0  Línea 7  L7. Glorieta de violeta   Mujer
# 1        1  Línea 7              L7. Reforma   Mujer
# 2        2  Línea 7            L7. Garibaldi   Mujer
# 3        3  Línea 7         L7. El caballito   Mujer
# 4        4  Línea 7              L7. Hidalgo   Mujer
# ...    ...      ...                      ...     ...
# 4037  4037  Línea 1              L1. Reforma  Hombre
# 4038  4038  Línea 1              L1. Reforma  Hombre
# 4039  4039  Línea 1        L1. Doctor Gálvez  Hombre
# 4040  4040  Línea 4     L4. Teatro de Pueblo  Hombre
# 4041  4041  Línea 1        L1. Doctor Gálvez  Hombre
#
#      5_1_usualmente_para_que_utiliza_el_metrobus  \
# 0                             Para ir al trabajo
# 1                             Para ir de compras
# 2                             Para ir al trabajo
# 3                             Para ir al trabajo
# 4                             Para ir al trabajo
# ...

# %%
print(df.columns)
# Out:
# Index(['id', 'linea', 'estacion', '4_sexo',
#        '5_1_usualmente_para_que_utiliza_el_metrobus',
#        '5_2_usualmente_para_que_utiliza_el_metrobus',
#        '5_3_usualmente_para_que_utiliza_el_metrobus',
#        '5_4_usualmente_para_que_utiliza_el_metrobus',
#        '5_5_usualmente_para_que_utiliza_el_metrobus',
#        '5_6_usualmente_para_que_utiliza_el_metrobus',
#        ...
#        '41_3_como_compara_al_metrobus_con_los_siguientes_medios_de_transporte',
#        '41_4_como_compara_al_metrobus_con_los_siguientes_medios_de_transporte',
#        '41_5_como_compara_al_metrobus_con_los_siguientes_medios_de_transporte',
#        '41_6_como_compara_al_metrobus_con_los_siguientes_medios_de_transporte',
#        '41_7_como_compara_al_metrobus_con_los_siguientes_medios_de_transporte',
#        '41_8_como_compara_al_metrobus_con_los_siguientes_medios_de_transporte',
#        '42_cuanto_gasta_en_transporte_en_un_mes_pesos',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4042 entries, 0 to 4041
# Columns: 184 entries, id to 45_cual_es_su_maximo_grado_de_estudios
# dtypes: float64(15), int64(1), object(168)
# memory usage: 5.7+ MB

# %%
#Exploración de columnas
filtro=df.filter(regex="18_")

# %%
filtro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4042 entries, 0 to 4041
# Data columns (total 11 columns):
#  #   Column                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                --------------  -----
#  0   18_1_de_una_escala_de_uno_a_diez_donde_1_es_muy_malo_y_10_es_excelente_como_califica_los_siguientes_  4035 non-null   float64
#  1   18_2_de_una_escala_de_uno_a_diez_donde_1_es_muy_malo_y_10_es_excelente_como_califica_los_siguientes_  4032 non-null   float64
#  2   18_3_de_una_escala_de_uno_a_diez_donde_1_es_muy_malo_y_10_es_excelente_como_califica_los_siguientes_  4028 non-null   float64
#  3   18_4_de_una_escala_de_uno_a_diez_donde_1_es_muy_malo_y_10_es_excelente_como_califica_los_siguientes_  4031 non-null   float64
# ...

# %%
filtro1=df.filter(regex="27_")
filtro1.columns
# Out:
# Index(['27_1_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d',
#        '27_2_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d',
#        '27_3_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d',
#        '27_4_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d',
#        '27_5_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d',
#        '27_6_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d',
#        '27_7_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d',
#        '27_8_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d'],
#       dtype='object')

# %%
for i in range(1,9):
  print(filtro1["27_{}_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d".format(i)].unique())
# Out:
# ['No' 'Sí'
#  '1. Palabras obscenas, insinuaciones sobre su cuerpo o apariencia'
#  'No contestó']
# ['No' 'Sí' '2. Miradas lascivas permanentes o incómodas a su cuerpo'
#  'No contestó']
# ['No' 'Sí' '3. Roce o contacto físico no deseado' 'No contestó']
# ['No' '4. Exhibición de genitales' 'Sí' 'No contestó']
# ['No' 'Sí' '5. Toma de fotos o video a su cuerpo, sin  consentimiento']
# ['No' 'Sí' '6. Chiflidos' 'No contestó']
# ['No' '7. Intento de violación' 'No contestó']
# ['No' 'No contestó' '8. Actividad sexual no deseada (Violación sexual)'
#  'Sí']

# %%
#1,2,3,4,5-2,6-1,7,8-1,14,15,16,24,25,26,28_all,29_all,31_all,40-1,44, borrar Vehiculo
df.filter(regex="4_").columns
# Out:
# Index(['4_sexo', '5_4_usualmente_para_que_utiliza_el_metrobus',
#        '6_4_ademas_del_metrobus_que_otros_medios_de_transporte_utiliza_en_un_dia_normal',
#        '8_4_porque_esta_utilizando_el_metrobus_en_lugar_de_su_vehiculo',
#        '12_4_por_que_deja_pasar_el_autobus',
#        '14_generalmente_transborda_dentro_del_metrobus_durante_su_recorrido_ida_y_vuelta',
#        '16_4_en_donde',
#        '18_4_de_una_escala_de_uno_a_diez_donde_1_es_muy_malo_y_10_es_excelente_como_califica_los_siguientes_',
#        '20_4_que_aspectos_mejoraria_del_servicio_de_metrobus',
#        '24_siente_que_en_el_metrobus_su_integridad_fisica_y_moral_esta_protegida',
#        '25_4_por_que_siente_usted_que_no_esta_protegida_su_integridad_fisica_y_moral',
#        '27_4_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d',
#        '28_4_quien_la_hizo', '29_4_fue_un_hombre_o_una_mujer',
# ...

# %%
dic={"5_1_usualmente_para_que_utiliza_el_metrobus":"uso 1",
     "4_sexo":"sexo",
    "6_1_ademas_del_metrobus_que_otros_medios_de_transporte_utiliza_en_un_dia_norma":"otros transportes",
     "8_1_porque_esta_utilizando_el_metrobus_en_lugar_de_su_vehiculo":"preferencia MB-auto",
     "14_generalmente_transborda_dentro_del_metrobus_durante_su_recorrido_ida_y_vuelta":"transbordos",
     "15_cuantas_veces_ida_y_vuelta":"num transbordos",
    "16_1_en_donde":"lugar transbordo",
     "24_siente_que_en_el_metrobus_su_integridad_fisica_y_moral_esta_protegida":"se siente protegido",
     "25_1_por_que_siente_usted_que_no_esta_protegida_su_integridad_fisica_y_moral":"razon proteccion",
     "26_esta_de_acuerdo_o_en_desacuerdo_con_la_separacion_entre_hombres_y_mujeres_en_el_metrobus":"opinion separacion",
    "27_1_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d":"palabras obscenas 1",
   "27_2_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d":"miradas lascivas 2",
     "27_3_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d":"contacto fisico 3",
    "27_4_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d":"exhibición de genitales 4",
    "27_5_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d":"toma de fotos o videos 5",
    "27_6_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d":"chiflidos 6",
    "27_7_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d":"intento de violacion 7",
     "27_8_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d":"violacion 8",
     "40_1_por_que_eligio_trasladarse_en_el_metrobus":"preferencia MB",
     "44_cuantos_anos_cumplidos_tiene":"edad"
  }

# %%
dic1={}
for i in range(1,9):
  ant="28_{}_quien_la_hizo".format(i)
  nue="razon {}".format(i)
  dic1[ant]=nue
dic1
# Out:
# {'28_1_quien_la_hizo': 'razon 1',
#  '28_2_quien_la_hizo': 'razon 2',
#  '28_3_quien_la_hizo': 'razon 3',
#  '28_4_quien_la_hizo': 'razon 4',
#  '28_5_quien_la_hizo': 'razon 5',
#  '28_6_quien_la_hizo': 'razon 6',
#  '28_7_quien_la_hizo': 'razon 7',
#  '28_8_quien_la_hizo': 'razon 8'}

# %%
dic2={}
for i in range(1,9):
  ant="29_{}_fue_un_hombre_o_una_mujer".format(i)
  nue="sexo {}".format(i)
  dic2[ant]=nue
dic2
# Out:
# {'29_1_fue_un_hombre_o_una_mujer': 'sexo 1',
#  '29_2_fue_un_hombre_o_una_mujer': 'sexo 2',
#  '29_3_fue_un_hombre_o_una_mujer': 'sexo 3',
#  '29_4_fue_un_hombre_o_una_mujer': 'sexo 4',
#  '29_5_fue_un_hombre_o_una_mujer': 'sexo 5',
#  '29_6_fue_un_hombre_o_una_mujer': 'sexo 6',
#  '29_7_fue_un_hombre_o_una_mujer': 'sexo 7',
#  '29_8_fue_un_hombre_o_una_mujer': 'sexo 8'}

# %%
dic3={}
for i in range(1,9):
  ant="31_{}_donde_ocurrio_el_evento".format(i)
  nue="ubicacion {}".format(i)
  dic3[ant]=nue
dic3
# Out:
# {'31_1_donde_ocurrio_el_evento': 'ubicacion 1',
#  '31_2_donde_ocurrio_el_evento': 'ubicacion 2',
#  '31_3_donde_ocurrio_el_evento': 'ubicacion 3',
#  '31_4_donde_ocurrio_el_evento': 'ubicacion 4',
#  '31_5_donde_ocurrio_el_evento': 'ubicacion 5',
#  '31_6_donde_ocurrio_el_evento': 'ubicacion 6',
#  '31_7_donde_ocurrio_el_evento': 'ubicacion 7',
#  '31_8_donde_ocurrio_el_evento': 'ubicacion 8'}

# %%
diccionario={}
diccionario.update(dic)
diccionario.update(dic1)
diccionario.update(dic2)
diccionario.update(dic3)
diccionario
# Out:
# {'5_1_usualmente_para_que_utiliza_el_metrobus': 'uso 1',
#  '4_sexo': 'sexo',
#  '6_1_ademas_del_metrobus_que_otros_medios_de_transporte_utiliza_en_un_dia_norma': 'otros transportes',
#  '8_1_porque_esta_utilizando_el_metrobus_en_lugar_de_su_vehiculo': 'preferencia MB-auto',
#  '14_generalmente_transborda_dentro_del_metrobus_durante_su_recorrido_ida_y_vuelta': 'transbordos',
#  '15_cuantas_veces_ida_y_vuelta': 'num transbordos',
#  '16_1_en_donde': 'lugar transbordo',
#  '24_siente_que_en_el_metrobus_su_integridad_fisica_y_moral_esta_protegida': 'se siente protegido',
#  '25_1_por_que_siente_usted_que_no_esta_protegida_su_integridad_fisica_y_moral': 'razon proteccion',
#  '26_esta_de_acuerdo_o_en_desacuerdo_con_la_separacion_entre_hombres_y_mujeres_en_el_metrobus': 'opinion separacion',
#  '27_1_en_los_ultimos_seis_meses_ha_sufrido_alguna_de_las_siguientes_situaciones_cuando_ha_hecho_uso_d': 'palabras obscenas 1',
# ...

# %%
#1,2,3,4,5-2,6-1,7,8-1,14,15,16,24,25,26,28_all,29_all,31_all,40-1,44, borrar Vehiculo
df.filter(regex="44_").columns
# Out:
# Index(['44_cuantos_anos_cumplidos_tiene'], dtype='object')

# %%
df.rename(columns=diccionario,inplace=True)

# %%
df.filter(like="_").columns
# Out:
# Index(['5_2_usualmente_para_que_utiliza_el_metrobus',
#        '5_3_usualmente_para_que_utiliza_el_metrobus',
#        '5_4_usualmente_para_que_utiliza_el_metrobus',
#        '5_5_usualmente_para_que_utiliza_el_metrobus',
#        '5_6_usualmente_para_que_utiliza_el_metrobus',
#        '5_7_usualmente_para_que_utiliza_el_metrobus',
#        '5_8_usualmente_para_que_utiliza_el_metrobus',
#        '5_9_usualmente_para_que_utiliza_el_metrobus',
#        '5_10_usualmente_para_que_utiliza_el_metrobus',
#        '5_11_usualmente_para_que_utiliza_el_metrobus',
#        ...
#        '41_2_como_compara_al_metrobus_con_los_siguientes_medios_de_transporte',
#        '41_3_como_compara_al_metrobus_con_los_siguientes_medios_de_transporte',
#        '41_4_como_compara_al_metrobus_con_los_siguientes_medios_de_transporte',
#        '41_5_como_compara_al_metrobus_con_los_siguientes_medios_de_transporte',
#        '41_6_como_compara_al_metrobus_con_los_siguientes_medios_de_transporte',
# ...

# %%
data=df.drop(columns=df.filter(like="_").columns)

# %%
data.head()
# Out:
#    id    linea                 estacion   sexo               uso 1  \
# 0   0  Línea 7  L7. Glorieta de violeta  Mujer  Para ir al trabajo
# 1   1  Línea 7              L7. Reforma  Mujer  Para ir de compras
# 2   2  Línea 7            L7. Garibaldi  Mujer  Para ir al trabajo
# 3   3  Línea 7         L7. El caballito  Mujer  Para ir al trabajo
# 4   4  Línea 7              L7. Hidalgo  Mujer  Para ir al trabajo
#
#                        preferencia MB-auto transbordos num transbordos  \
# 0                                No aplica          No       No aplica
# 1                                No aplica          Sí               2
# 2                                No aplica          No       No aplica
# 3                                No aplica          No       No aplica
# 4  Porqué es más rápido viajar en Metrobús          No       No aplica
#
#   lugar transbordo se siente protegido  ... ubicacion 1 ubicacion 2  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4041 entries, 0 to 4041
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         4041 non-null   int64
#  1   linea                      4041 non-null   object
#  2   estacion                   4041 non-null   object
#  3   sexo                       4041 non-null   object
#  4   uso 1                      4041 non-null   object
#  5   preferencia MB-auto        4041 non-null   object
#  6   transbordos                4041 non-null   object
#  7   num transbordos            4041 non-null   object
#  8   lugar transbordo           4041 non-null   object
#  9   se siente protegido        4041 non-null   object
#  10  razon proteccion           4041 non-null   object
#  11  opinion separacion         4041 non-null   object
#  12  palabras obscenas 1        4041 non-null   object
# ...

# %%
data = data.dropna()

# %%
data.linea.unique()
# Out:
# array(['Línea 7', 'Línea 1', 'Línea 5', 'Línea 4', 'Línea 2', 'Línea 3',
#        'Línea 6'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4041 entries, 0 to 4041
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         4041 non-null   int64
#  1   linea                      4041 non-null   object
#  2   estacion                   4041 non-null   object
#  3   sexo                       4041 non-null   object
#  4   uso 1                      4041 non-null   object
#  5   preferencia MB-auto        4041 non-null   object
#  6   transbordos                4041 non-null   object
#  7   num transbordos            4041 non-null   object
#  8   lugar transbordo           4041 non-null   object
#  9   se siente protegido        4041 non-null   object
#  10  razon proteccion           4041 non-null   object
#  11  opinion separacion         4041 non-null   object
#  12  palabras obscenas 1        4041 non-null   object
# ...

# %%
data.to_csv("encuesta1.csv",index=False)
